# %% [markdown]
# ### 1. Expand the flask app from class to add functions to create, update, and delete records. Use the mongodb documentation https://docs.mongodb.com/manual/reference/ . Create can use insert_one method, update can use update_one, and delete can use delete_one.

# %% [markdown]
# ![first.PNG](attachment:first.PNG)

# %% [markdown]
# after adding the second record output is as shown in below cell

# %% [markdown]
# ![second.PNG](attachment:second.PNG)

# %% [markdown]
# after deleting the second record output is shown as below cell

# %% [markdown]
# ![three.PNG](attachment:three.PNG)

# %% [markdown]
# after updating year in second record output is shown in below cell

# %% [markdown]
# ![four.PNG](attachment:four.PNG)
